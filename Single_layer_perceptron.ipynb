# %% [markdown]
# <a href="https://colab.research.google.com/github/saleem-007/AI_Practice1/blob/main/Single_layer_perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
#Given data
x = np.array([1.0,2.0])   #Inputs
y = 1                     #Target
w = np.array([0.2, -0.5]) #Initial weights
b = 0.1                   #Initial bias
eta = 0.1                 #Learning rate

# %%
# Run for 3 epochs
for epoch in range (1,4):
  print(f"\nEpoch {epoch}:")
  net_input =np.dot(w,x)+b
  y_pred= 1 if net_input > 0 else 0
  error = y - y_pred

  print(f" Net input = {net_input:.2f}")
  print(f" Predicted output = {y_pred}")
  print(f" Error = {error}")

  #Updated rule
  w = w + eta * error * x
  b = b + eta * error


  print(f" Updated weights = {w}")
  print(f" Updated bias = {b:.2f}")
